# %% [markdown]
# # 画像変換AI
#
# 好きな画像をアイコンへと変換できます．
#
# Shift + Enterを押すとプログラムが開始します．
#
# 使い方が分からない方は，　webトークで聞いてみてください．
#
# 画像をどんどんアイコン化しよう！！！

# %% [markdown]
# ![image](http://human.ait.kyushu-u.ac.jp/opencampas/pic2icon.png)

# %% [markdown]
# **AIモデルをダウンロード**

# %%
# %%shell
#
# git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix.git
# %cd pytorch-CycleGAN-and-pix2pix
#
# wget http://human.ait.kyushu-u.ac.jp/opencampas/uchida.png
# wget https://www.ana.co.jp/domtour/area/akita/assets/img/page/img_main_akita_dog_sp.jpg
# wget http://human.ait.kyushu-u.ac.jp/opencampas/300_net_G_A.pth
# Out:
# UsageError: Cell magic `%%shell` not found.

# %% [markdown]
# # 새 섹션

# %%
from models.networks import define_G
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
from models.networks import define_G
import torchvision.transforms as transforms
import torch

iimg_name = "img_main_akita_dog_sp.jpg"
img = Image.open(img_name)
plt.imshow(img), plt.show()

model = define_G(3, 3, 64, 'resnet_9blocks', 'instance', False, 'normal', 0.02, [])
model.load_state_dict(torch.load('300_net_G_A.pth'))
model.eval()

img = img.convert('RGB')

transformer = []
transformer.append(transforms.Resize((256,256),3))
transformer.append(transforms.ToTensor())
transformer.append(transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)))
transformer = transforms.Compose(transformer)

img = transformer(img)
pred = model(img.unsqueeze(0))
pred = pred[0].detach().numpy().transpose(1,2,0)
plt.imshow(pred), plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-603d5edfb01b> in <module>()
# ----> 1 from models.networks import define_G
#       2 import matplotlib.pyplot as plt
#       3 from PIL import Image
#       4 import numpy as np
#       5 from models.networks import define_G
#
# ModuleNotFoundError: No module named 'models'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
img_name = "uchida.png"
img = Image.open(img_name)
plt.imshow(img), plt.show()

model = define_G(3, 3, 64, 'resnet_9blocks', 'instance', False, 'normal', 0.02, [])
model.load_state_dict(torch.load('300_net_G_A.pth'))
model.eval()

img = img.convert('RGB')

transformer = []
transformer.append(transforms.Resize((256,256),3))
transformer.append(transforms.ToTensor())
transformer.append(transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)))
transformer = transforms.Compose(transformer)

img = transformer(img)
pred = model(img.unsqueeze(0))
pred = pred[0].detach().numpy().transpose(1,2,0)
plt.imshow(pred), plt.show()
# Out:
# initialize network with normal
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (<matplotlib.image.AxesImage at 0x7fcc7b17e240>, None)
