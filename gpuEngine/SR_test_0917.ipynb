# %%
import numpy as np
from PIL import Image
from ISR.models import RDN
from ISR.models import RRDN

# %%
#img = Image.open('data/input/sample/SR_test_0.png')
#img = Image.open('data/input/sample/meerkat.png')
#img = Image.open('data/input/sample/SR_test_kjh.jpg')
#img = Image.open('data/input/sample/SR_test_family.jpg')
#img = Image.open('data/input/sample/SR_test_father.jpg')
img = Image.open('data/input/sample/dk_0014.jpg')
lr_img = np.array(img)
Image.fromarray(lr_img)
# Out:
# <PIL.Image.Image image mode=RGB size=59x196 at 0x7FF161A1BB38>

# %%
rdn = RDN(weights='psnr-small')
sr_img_rdn = rdn.predict(lr_img)
Image.fromarray(sr_img_rdn)
# Out:
# <PIL.Image.Image image mode=RGB size=118x392 at 0x7FF1507739E8>

# %%
model = RRDN(weights = 'gans')
sr_img_gan = model.predict(lr_img)
Image.fromarray(sr_img_gan)
# Out:
# <PIL.Image.Image image mode=RGB size=236x784 at 0x7FF0D444B1D0>

# %%
sr_img = model.predict(image, by_patch_of_size=50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-5a7ad069d559> in <module>
# ----> 1 sr_img = model.predict(image, by_patch_of_size=50)
#
# NameError: name 'image' is not defined
